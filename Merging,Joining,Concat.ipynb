# %%
import numpy as np
import pandas as pd

# %%
pip install --upgrade pandas
# Out:
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/77/62/8e11962934e024a093758992bc82711e3e30efd5ea355cbfdc6e1ab5de76/pandas-2.2.0-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.6 MB 7.7 MB/s eta 0:00:02
#    -- ------------------------------------- 0.8/11.6 MB 10.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.4/11.6 MB 10.8 MB/s eta 0:00:01
#    ------ --------------------------------- 1.9/11.6 MB 11.3 MB/s eta 0:00:01
#    -------- ------------------------------- 2.5/11.6 MB 11.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.1/11.6 MB 11.4 MB/s eta 0:00:01
#    ------------ --------------------------- 3.5/11.6 MB 11.1 MB/s eta 0:00:01
#    ------------- -------------------------- 4.0/11.6 MB 11.2 MB/s eta 0:00:01
#    --------------- ------------------------ 4.5/11.6 MB 11.6 MB/s eta 0:00:01
# ...

# %%
course=pd.read_csv('courses.csv')
students=pd.read_csv('students.csv')
nov=pd.read_csv('reg-month1.csv')
dec=pd.read_csv('reg-month2.csv')

matches=pd.read_csv('matches.csv')
delivery=pd.read_csv('deliveries.csv')

# %%
dec
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
#pd.concat
#df.concat
#ignore_index
#df.append
#mullitindex -> fetch using iloc
#concat dataframes horizontally

# %%
#Concat two dataset
regs= pd.concat([nov,dec],ignore_index=True)
regs
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# ...

# %%
#axis=1 columns & axis=0 rows
multi=pd.concat([nov,dec],keys=['Nov','Dec'],axis=1)
multi.head(5)
# Out:
#          Nov                  Dec
#   student_id course_id student_id course_id
# 0       23.0       1.0          3         5
# 1       15.0       5.0         16         7
# 2       18.0       6.0         12        10
# 3       23.0       4.0         12         1
# 4       16.0       9.0         14         9

# %%
multi.loc[4,'Dec']
# Out:
# student_id    14.0
# course_id      9.0
# Name: 4, dtype: float64

# %%
regs.head(5)
# Out:
#    student_id  course_id
# 0          23          1
# 1          15          5
# 2          18          6
# 3          23          4
# 4          16          9

# %%
students.head(5)
# Out:
#    student_id            name  partner
# 0           1   Kailash Harjo       23
# 1           2     Esha Butala        1
# 2           3  Parveen Bhalla        3
# 3           4     Marlo Dugal       14
# 4           5     Kusum Bahri        6

# %%
#inner join
# on: Specifies the column(s) to join on.
# how: Specifies the type of join (e.g., 'inner', 'outer', 'left', 'right').
students.merge(regs,how='left',on='student_id').head(5)
# Out:
#    student_id           name  partner  course_id
# 0           1  Kailash Harjo       23        1.0
# 1           1  Kailash Harjo       23        6.0
# 2           1  Kailash Harjo       23       10.0
# 3           1  Kailash Harjo       23        9.0
# 4           2    Esha Butala        1        5.0

# %%
regs.head(2)
# Out:
#    student_id  course_id
# 0          23          1
# 1          15          5

# %%
students.head(2)
# Out:
#    student_id           name  partner
# 0           1  Kailash Harjo       23
# 1           2    Esha Butala        1

# %%
students.merge(regs).head(3)
# Out:
#    student_id           name  partner  course_id
# 0           1  Kailash Harjo       23          1
# 1           1  Kailash Harjo       23          6
# 2           1  Kailash Harjo       23         10

# %%
course['price'].sum()
# Out:
# 33288

# %%
#1 find total revenue generated
total= regs.merge(course,how='inner',on='course_id')
revenue_of_python_course=total[total['course_id']==1]['price'].sum()

# %%
merge=regs.merge(course)
merge.head(20)
# Out:
#     student_id  course_id       course_name  price
# 0           23          1            python   2499
# 1           15          5           tableau   2499
# 2           18          6          power bi   1899
# 3           23          4  machine learning   9999
# 4           16          9            plotly    699
# 5           18          1            python   2499
# 6            1          1            python   2499
# 7            7          8            pandas   1099
# 8           22          3     data analysis   4999
# 9           15          1            python   2499
# 10          19          4  machine learning   9999
# 11           1          6          power bi   1899
# 12           7         10           pyspark   2499
# 13          11          7          ms sxcel   1599
# 14          13          3     data analysis   4999
# 15          24          4  machine learning   9999
# 16          21          1            python   2499
# ...

# %%
# Assuming 'regs' and 'course' are DataFrames, and you want to find revenue for course_id = 1

#find total Revenue of the course python with course_id
total_revenue_course_1 = regs.merge(course, how='inner', on='course_id')
total_revenue_course_1 = total_revenue_course_1[total_revenue_course_1['course_id']==1]['price'].sum()

print(total_revenue_course_1)
# Out:
# 22491

# %%
#find month by month revenue
temp_df=pd.concat([nov,dec],keys=['Nov','Dec']).reset_index()
temp_df.merge(course,on='course_id').groupby('level_0')['price'].sum()
# Out:
# level_0
# Dec    65072
# Nov    89175
# Name: price, dtype: int64

# %%
#Find the revenue based on the course name of Nov &dec
temp_df=temp_df.merge(course)
temp_df[temp_df['course_name']=='python'].groupby('level_0')['price'].sum()
# Out:
# level_0
# Dec     7497
# Nov    14994
# Name: price, dtype: int64

# %%
#Print registration Table
regs.merge(students,).merge(course)[['name','course_name','price']].head(5)

# %%
regs.head(3)

# %%
course.head(3)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'regs' and 'courses' are DataFrames
course_revenue=regs.merge(course, on='course_id').groupby('course_name')['price'].sum()
course_revenue
# Out:
# course_name
# data analysis       24995
# machine learning    39996
# ms sxcel             7995
# pandas               4396
# plotly               3495
# power bi            11394
# pyspark             14994
# python              22491
# sql                  6998
# tableau             17493
# Name: price, dtype: int64

# %%
#find students that enrolled in both months
common_student_id=np.intersect1d(nov['student_id'],dec['student_id'])
common_student_id
# Out:
# array([ 1,  3,  7, 11, 16, 17, 18, 22, 23], dtype=int64)

# %%
students[students['student_id'].isin(common_student_id)]
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 2            3      Parveen Bhalla        3
# 6            7        Tarun Thaker        9
# 10          11  David Mukhopadhyay       20
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 21          22          Yash Sethi       21
# 22          23      Chhavi Lachman       18

# %%
#find course that got no enrollement
course_id=np.setdiff1d(course['course_id'],regs['course_id'])
course_id
# Out:
# array([11, 12], dtype=int64)

# %%
course[course['course_id'].isin(course_id)]
# Out:
#     course_id course_name  price
# 10         11       Numpy    699
# 11         12         C++   1299

# %%
#find student who not enrolled in any course
student_id=np.setdiff1d(students['student_id'],course['course_id'])
student_id.shape[0]

(10/28)*100
# Out:
# 35.714285714285715

# %%
students[students['student_id'].isin(student_id)]
# Out:
#     student_id              name  partner
# 12          13    Munni Varghese       24
# 13          14  Pranab Natarajan       22
# 14          15         Preet Sha       16
# 15          16      Elias Dodiya       25
# 16          17      Yasmin Palan        7
# 17          18   Fardeen Mahabir       13
# 18          19      Qabeel Raman       12
# 19          20     Hanuman Hegde       11
# 20          21        Seema Kota       15
# 21          22        Yash Sethi       21
# 22          23    Chhavi Lachman       18
# 23          24      Radhika Suri       17
# 24          25   Shashank D’Alia        2

# %%
# Print student Name partner name for all enrolled students
students.merge(students,how='inner',left_on='partner',right_on='student_id')
# Out:
#     student_id_x              name_x  partner_x  student_id_y  \
# 0              1       Kailash Harjo         23            23
# 1              2         Esha Butala          1             1
# 2              3      Parveen Bhalla          3             3
# 3              4         Marlo Dugal         14            14
# 4              5         Kusum Bahri          6             6
# 5              6  Lakshmi Contractor         10            10
# 6              7        Tarun Thaker          9             9
# 7              8      Radheshyam Dey          5             5
# 8              9   Nitika Chatterjee          4             4
# 9             10      Aayushman Sant          8             8
# 10            11  David Mukhopadhyay         20            20
# 11            12          Radha Dutt         19            19
# 12            13      Munni Varghese         24            24
# 13            14    Pranab Natarajan         22            22
# ...
